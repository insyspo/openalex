# %% [markdown]
# <a href="https://colab.research.google.com/github/insyspo/openalex/blob/main/OpenAlex_create_tables_2024_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Code to create relational model for OpenAlex
#
# The following code using the set of tables created previoulsy with every entity as a single table with one column. The whole entity is was stored as a single JSON entry in those tables. Here they are exploded into several tables connected by their identifiers.

# %% [markdown]
# # Preparation

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
# %%bigquery --project=stone-ground-401723
#
# CREATE SCHEMA publicdb_openalex_2024_04_rm;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Tables
#
#
# [OpenAlex entities](https://docs.openalex.org/api-entities/entities-overview)

# %% [markdown]
# ## First level tables

# %% [markdown]
# ### Authors

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.authors;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.authors AS (
#   SELECT  CAST(SPLIT(TRIM(JSON_EXTRACT(author, '$.id'),'"'),'/A')[1] AS INT64) AS id,
#     TRIM(JSON_EXTRACT(author, '$.display_name'),'"') AS display_name,
#     TRIM(JSON_EXTRACT(author, '$.orcid'),'"') AS orcid,
#     CAST(TRIM(JSON_EXTRACT(author, '$.cited_by_count'),'"') AS INT64) AS cited_by_count,
#     TRIM(JSON_EXTRACT(author, '$.most_cited_work'),'"') AS most_cited_work,
#     CAST(TRIM(JSON_EXTRACT(author, '$.created_date'),'"') AS DATETIME) AS created_date,
#     CAST(TRIM(JSON_EXTRACT(author, '$.updated_date'),'"') AS DATETIME) AS updated_date,
#     CAST(TRIM(JSON_EXTRACT(author, '$.works_count'),'"') AS INT64) AS works_count,
#     CAST(TRIM(JSON_EXTRACT(author, '$.updated'),'"') AS DATETIME) AS updated,
#     TRIM(JSON_EXTRACT(author, '$.last_known_institution'),'"') AS last_known_institution,
#   FROM `stone-ground-401723.publicdb_openalex_2024_04.authors`
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Concepts

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.concepts;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.concepts AS (
#   SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(concept, '$.id'),'"'),'/C')[1] AS INT64) AS id,
#     TRIM(JSON_EXTRACT(concept, '$.display_name'),'"') AS display_name,
#     CAST(TRIM(JSON_EXTRACT(concept, '$.cited_by_count'),'"') AS INT64) AS cited_by_count,
#     CAST(TRIM(JSON_EXTRACT(concept, '$.created_date'),'"') AS DATETIME) AS created_date,
#     CAST(TRIM(JSON_EXTRACT(concept, '$.updated_date'),'"') AS DATETIME) AS updated_date,
#     CAST(TRIM(JSON_EXTRACT(concept, '$.works_count'),'"') AS INT64) AS works_count,
#     CAST(TRIM(JSON_EXTRACT(concept, '$.updated'),'"') AS DATETIME) AS updated,
#     TRIM(JSON_EXTRACT(concept, '$.description'),'"') AS description,
#     TRIM(JSON_EXTRACT(concept, '$.image_url'),'"') AS image_url,
#     TRIM(JSON_EXTRACT(concept, '$.image_thumbnail_url'),'"') AS image_thumbnail_url,
#     TRIM(JSON_EXTRACT(concept, '$.works_api_url'),'"') AS works_api_url,
#     CAST(TRIM(JSON_EXTRACT(concept, '$.level'),'"') AS INT64) AS level,
#   FROM `stone-ground-401723.publicdb_openalex_2024_04.concepts`
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Funders

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.funders;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.funders AS (
#   SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(funder, '$.id'),'"'),'F')[1] AS INT64) AS id,
#     TRIM(JSON_EXTRACT(funder, '$.grants_count'),'"') AS grants_count,
#     CAST(TRIM(JSON_EXTRACT(funder, '$.cited_by_count'),'"') AS INT64) AS cited_by_count,
#     TRIM(JSON_EXTRACT(funder, '$.image_thumbnail_url'),'"') AS image_thumbnail_url,
#     TRIM(JSON_EXTRACT(funder, '$.image_url'),'"') AS image_url,
#     TRIM(JSON_EXTRACT(funder, '$.homepage_url'),'"') AS homepage_url,
#     TRIM(JSON_EXTRACT(funder, '$.description'),'"') AS description,
#     TRIM(JSON_EXTRACT(funder, '$.display_name'),'"') AS display_name,
#     TRIM(JSON_EXTRACT(funder, '$.country_code'),'"') AS country_code,
#     CAST(TRIM(JSON_EXTRACT(funder, '$.updated_date'),'"') AS DATETIME) AS updated_date,
#     CAST(TRIM(JSON_EXTRACT(funder, '$.created_date'),'"') AS DATETIME) AS created_date,
#     CAST(TRIM(JSON_EXTRACT(funder, '$.works_count'),'"') AS INT64) AS works_count,
#     CAST(TRIM(JSON_EXTRACT(funder, '$.updated'),'"') AS DATETIME) AS updated,
#  FROM `stone-ground-401723.publicdb_openalex_2024_04.funders`
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Institutions

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.institutions;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.institutions AS (
#   SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(institution, '$.id'),'"'),'/I')[1] AS INT64) AS id,
#     TRIM(JSON_EXTRACT(institution, '$.image_thumbnail_url'),'"') AS image_thumbnail_url,
#     TRIM(JSON_EXTRACT(institution, '$.homepage_url'),'"') AS homepage_url,
#     TRIM(JSON_EXTRACT(institution, '$.type'),'"') AS type,
#     TRIM(JSON_EXTRACT(institution, '$.ror'),'"') AS ror,
#     TRIM(JSON_EXTRACT(institution, '$.works_api_url'),'"') AS works_api_url,
#     CAST(TRIM(JSON_EXTRACT(institution, '$.cited_by_count'),'"') AS INT64) AS cited_by_count,
#     TRIM(JSON_EXTRACT(institution, '$.image_url'),'"') AS image_url,
#     TRIM(JSON_EXTRACT(institution, '$.display_name'),'"') AS display_name,
#     TRIM(JSON_EXTRACT(institution, '$.country_code'),'"') AS country_code,
#     CAST(TRIM(JSON_EXTRACT(institution, '$.updated_date'),'"') AS DATETIME) AS updated_date,
#     CAST(TRIM(JSON_EXTRACT(institution, '$.created_date'),'"') AS DATETIME) AS created_date,
#     CAST(TRIM(JSON_EXTRACT(institution, '$.works_count'),'"') AS INT64) AS works_count,
#     CAST(TRIM(JSON_EXTRACT(institution, '$.updated'),'"') AS DATETIME) AS updated,
#     TRIM(JSON_EXTRACT(institution,'$.geo.country_code'),'"') AS geo_country_code,
#     TRIM(JSON_EXTRACT(institution,'$.geo.country'),'"') AS country,
#     TRIM(JSON_EXTRACT(institution,'$.geo.city'),'"') AS city,
#     CAST(TRIM(JSON_EXTRACT(institution,'$.geo.latitude'),'"') AS FLOAT64) AS latitude,
#     CAST(TRIM(JSON_EXTRACT(institution,'$.geo.longitude'),'"') AS FLOAT64) AS longitude,
#     TRIM(JSON_EXTRACT(institution,'$.geo.geonames_city_id'),'"') AS geonames_city_id,
#     TRIM(JSON_EXTRACT(institution,'$.geo.region'),'"') AS region
#  FROM `stone-ground-401723.publicdb_openalex_2024_04.institutions`
#
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Publishers

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.publishers;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.publishers AS (
#   SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(publisher, '$.id'),'"'),'/P')[1] AS INT64) AS id,
#     TRIM(JSON_EXTRACT(publisher, '$.homepage_url'),'"') AS homepage_url,
#     TRIM(JSON_EXTRACT(publisher, '$.parent_publisher'),'"') AS parent_publisher,
#     TRIM(JSON_EXTRACT(publisher, '$.sources_api_url'),'"') AS sources_api_url,
#     CAST(TRIM(JSON_EXTRACT(publisher, '$.cited_by_count'),'"') AS INT64) AS cited_by_count,
#     TRIM(JSON_EXTRACT(publisher, '$.image_url'),'"') AS image_url,
#     TRIM(JSON_EXTRACT(publisher, '$.image_thumbnail_url'),'"') AS image_thumbnail_url,
#     TRIM(JSON_EXTRACT(publisher, '$.display_name'),'"') AS display_name,
#     CAST(TRIM(JSON_EXTRACT(publisher, '$.updated_date'),'"') AS DATETIME) AS updated_date,
#     CAST(TRIM(JSON_EXTRACT(publisher, '$.created_date'),'"') AS DATETIME) AS created_date,
#     CAST(TRIM(JSON_EXTRACT(publisher, '$.works_count'),'"') AS INT64) AS works_count,
#     CAST(TRIM(JSON_EXTRACT(publisher, '$.hierarchy_level'),'"') AS INT64) AS hierarchy_level,
#     CAST(TRIM(JSON_EXTRACT(publisher, '$.sources_count'),'"') AS INT64) AS sources_count,
#     CAST(TRIM(JSON_EXTRACT(publisher, '$.updated'),'"') AS DATETIME) AS updated,
#  FROM `stone-ground-401723.publicdb_openalex_2024_04.publishers`
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Sources

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.sources;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.sources AS (
#   SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(source, '$.id'),'"'),'/S')[1] AS INT64) AS id,
#     TRIM(JSON_EXTRACT(source, '$.publisher_id'),'"') AS publisher_id,
#     CAST(TRIM(JSON_EXTRACT(source, '$.is_in_doaj'),'"') AS BOOL) AS is_in_doaj,
#     TRIM(JSON_EXTRACT(source, '$.issn_l'),'"') AS issn_l,
#     TRIM(JSON_EXTRACT(source, '$.homepage_url'),'"') AS homepage_url,
#     TRIM(JSON_EXTRACT(source, '$.type'),'"') AS type,
#     TRIM(JSON_EXTRACT(source, '$.abbreviated_title'),'"') AS abbreviated_title,
#     TRIM(JSON_EXTRACT(source, '$.works_api_url'),'"') AS works_api_url,
#     TRIM(JSON_EXTRACT(source, '$.host_organization'),'"') AS host_organization,
#     CAST(TRIM(JSON_EXTRACT(source, '$.apc_usd'),'"') AS FLOAT64) AS apc_usd,
#     CAST(TRIM(JSON_EXTRACT(source, '$.cited_by_count'),'"') AS INT64) AS cited_by_count,
#     TRIM(JSON_EXTRACT(source, '$.display_name'),'"') AS display_name,
#     TRIM(JSON_EXTRACT(source, '$.host_organization_name'),'"') AS host_organization_name,
#     TRIM(JSON_EXTRACT(source, '$.country_code'),'"') AS country_code,
#     TRIM(JSON_EXTRACT(source, '$.issn'),'"') AS issn,
#     TRIM(JSON_EXTRACT(source, '$.publisher'),'"') AS publisher,
#     CAST(TRIM(JSON_EXTRACT(source, '$.is_oa'),'"') AS BOOL) AS is_oa,
#     CAST(TRIM(JSON_EXTRACT(source, '$.updated_date'),'"') AS DATETIME) AS updated_date,
#     CAST(TRIM(JSON_EXTRACT(source, '$.created_date'),'"') AS DATETIME) AS created_date,
#     CAST(TRIM(JSON_EXTRACT(source, '$.works_count'),'"') AS INT64) AS works_count,
#     CAST(TRIM(JSON_EXTRACT(source, '$.updated'),'"') AS DATETIME) AS updated,
#  FROM `stone-ground-401723.publicdb_openalex_2024_04.sources`
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Works

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.works;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.works AS (
#   SELECT
#     CAST(SPLIT(TRIM(JSON_EXTRACT(work, '$.id'),'"'),'/W')[1] AS INT64) AS id,
#     CAST(TRIM(JSON_EXTRACT(work, '$.is_retracted'),'"') AS BOOL) AS is_retracted,
#     TRIM(JSON_EXTRACT(work, '$.display_name'),'"') AS display_name,
#     TRIM(JSON_EXTRACT(work, '$.title'),'"') AS title,
#     CAST(TRIM(JSON_EXTRACT(work, '$.institutions_distinct_count'),'"') AS INT64) AS institutions_distinct_count,
#     CAST(TRIM(JSON_EXTRACT(work, '$.locations_count'),'"') AS INT64) AS locations_count,
#     CAST(TRIM(JSON_EXTRACT(work, '$.referenced_works_count'),'"') AS INT64) AS referenced_works_count,
#     CAST(TRIM(JSON_EXTRACT(work, '$.authors_count'),'"') AS INT64) AS authors_count,
#     CAST(TRIM(JSON_EXTRACT(work, '$.concepts_count'),'"') AS INT64) AS concepts_count,
#     CAST(TRIM(JSON_EXTRACT(work, '$.cited_by_count'),'"') AS INT64) AS cited_by_count,
#     TRIM(JSON_EXTRACT(work, '$.type'),'"') AS type,
#     TRIM(JSON_EXTRACT(work, '$.cited_by_api_url'),'"') AS cited_by_api_url,
#     CAST(TRIM(JSON_EXTRACT(work, '$.is_paratext'),'"') AS BOOL) AS is_paratext,
#     CAST(TRIM(JSON_EXTRACT(work, '$.created_date'),'"') AS DATETIME) AS created_date,
#     CAST(TRIM(JSON_EXTRACT(work, '$.publication_date'),'"') AS DATETIME) AS publication_date,
#     COALESCE(
#       CAST(SAFE.PARSE_TIMESTAMP('%FT%H:%M:%E*SZ',
#               TRIM(JSON_EXTRACT(work, '$.updated'),'"')) AS DATETIME),
#       CAST(TRIM(JSON_EXTRACT(work, '$.updated'),'"') AS DATETIME)
#     ) AS updated,
#     CAST(TRIM(JSON_EXTRACT(work, '$.updated_date'),'"') AS DATETIME) AS updated_date,
#     CAST(TRIM(JSON_EXTRACT(work, '$.publication_year'),'"') AS INT64) AS publication_year,
#     SUBSTR(TRIM(JSON_EXTRACT(work, '$.doi'),'"'),17) AS doi,
#     TRIM(JSON_EXTRACT(work, '$.language'),'"') AS language,
#     TRIM(JSON_EXTRACT(work, '$.open_access.oa_status'),'"') AS oa_status,
#     TRIM(JSON_EXTRACT(work, '$.open_access.oa_url'),'"') AS oa_url,
#     CAST(TRIM(JSON_EXTRACT(work, '$.open_access.is_oa'),'"') AS BOOL) AS is_oa,
#     CAST(TRIM(JSON_EXTRACT(work, '$.open_access.any_repository_has_full_text'),'"') AS BOOL) AS any_repository_has_full_text,
#  FROM `stone-ground-401723.publicdb_openalex_2024_04.works`
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Topics

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.topics;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.topics AS (
#   SELECT
#     CAST(SPLIT(TRIM(JSON_EXTRACT(topic, '$.id'),'"'),'/T')[1] AS INT64) AS id,
#     TRIM(JSON_EXTRACT(topic, '$.display_name'),'"') AS display_name,
#     TRIM(JSON_EXTRACT(topic, '$.description'),'"') AS description,
#     CAST(TRIM(JSON_EXTRACT(topic, '$.works_count'),'"') AS INT64) AS works_count,
#     CAST(TRIM(JSON_EXTRACT(topic, '$.cited_by_count'),'"') AS INT64) AS cited_by_count,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(topic, '$.subfield.id'),'"'),'subfields/')[1] AS INT64) AS subfield,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(topic, '$.field.id'),'"'),'fields/')[1] AS INT64) AS field,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(topic, '$.domain.id'),'"'),'domains/')[1] AS INT64) AS domain,
#     TRIM(JSON_EXTRACT(topic, '$.works_api_url'),'"') AS works_api_url,
#     CAST(TRIM(JSON_EXTRACT(topic, '$.created_date'),'"') AS DATETIME) AS created_date,
#     COALESCE(
#       CAST(SAFE.PARSE_TIMESTAMP('%FT%H:%M:%E*SZ',
#               TRIM(JSON_EXTRACT(topic, '$.updated'),'"')) AS DATETIME),
#       CAST(TRIM(JSON_EXTRACT(topic, '$.updated'),'"') AS DATETIME)
#     ) AS updated,
#     CAST(TRIM(JSON_EXTRACT(topic, '$.updated_date'),'"') AS DATETIME) AS updated_date,
#   FROM `stone-ground-401723.publicdb_openalex_2024_04.topics`
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Domains

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.domains;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.domains AS (
#   SELECT
#     CAST(SPLIT(TRIM(JSON_EXTRACT(domain, '$.id'),'"'),'domains/')[1] AS INT64) AS id,
#     TRIM(JSON_EXTRACT(domain, '$.display_name'),'"') AS display_name,
#     TRIM(JSON_EXTRACT(domain, '$.description'),'"') AS description,
#     CAST(TRIM(JSON_EXTRACT(domain, '$.works_count'),'"') AS INT64) AS works_count,
#     CAST(TRIM(JSON_EXTRACT(domain, '$.cited_by_count'),'"') AS INT64) AS cited_by_count,
#     TRIM(JSON_EXTRACT(domain, '$.works_api_url'),'"') AS works_api_url,
#     CAST(TRIM(JSON_EXTRACT(domain, '$.created_date'),'"') AS DATETIME) AS created_date,
#     COALESCE(
#       CAST(SAFE.PARSE_TIMESTAMP('%FT%H:%M:%E*SZ',
#               TRIM(JSON_EXTRACT(domain, '$.updated'),'"')) AS DATETIME),
#       CAST(TRIM(JSON_EXTRACT(domain, '$.updated'),'"') AS DATETIME)
#     ) AS updated,
#     CAST(TRIM(JSON_EXTRACT(domain, '$.updated_date'),'"') AS DATETIME) AS updated_date,
#   FROM `stone-ground-401723.publicdb_openalex_2024_04.domains`
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Fields

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.fields;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.fields AS (
#   SELECT
#     CAST(SPLIT(TRIM(JSON_EXTRACT(field, '$.id'),'"'),'fields/')[1] AS INT64) AS id,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(field, '$.domain.id'),'"'),'domains/')[1] AS INT64) AS domain_id,
#     TRIM(JSON_EXTRACT(field, '$.display_name'),'"') AS display_name,
#     TRIM(JSON_EXTRACT(field, '$.description'),'"') AS description,
#     CAST(TRIM(JSON_EXTRACT(field, '$.works_count'),'"') AS INT64) AS works_count,
#     CAST(TRIM(JSON_EXTRACT(field, '$.cited_by_count'),'"') AS INT64) AS cited_by_count,
#     TRIM(JSON_EXTRACT(field, '$.works_api_url'),'"') AS works_api_url,
#     CAST(TRIM(JSON_EXTRACT(field, '$.created_date'),'"') AS DATETIME) AS created_date,
#     COALESCE(
#       CAST(SAFE.PARSE_TIMESTAMP('%FT%H:%M:%E*SZ',
#               TRIM(JSON_EXTRACT(field, '$.updated'),'"')) AS DATETIME),
#       CAST(TRIM(JSON_EXTRACT(field, '$.updated'),'"') AS DATETIME)
#     ) AS updated,
#     CAST(TRIM(JSON_EXTRACT(field, '$.updated_date'),'"') AS DATETIME) AS updated_date,
#   FROM `stone-ground-401723.publicdb_openalex_2024_04.fields`
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Subfields

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.subfields;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.subfields AS (
#   SELECT
#     CAST(SPLIT(TRIM(JSON_EXTRACT(subfield, '$.id'),'"'),'subfields/')[1] AS INT64) AS id,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(subfield, '$.field.id'),'"'),'fields/')[1] AS INT64) AS field_id,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(subfield, '$.domain.id'),'"'),'domains/')[1] AS INT64) AS domain_id,
#     TRIM(JSON_EXTRACT(subfield, '$.display_name'),'"') AS display_name,
#     TRIM(JSON_EXTRACT(subfield, '$.description'),'"') AS description,
#     CAST(TRIM(JSON_EXTRACT(subfield, '$.works_count'),'"') AS INT64) AS works_count,
#     CAST(TRIM(JSON_EXTRACT(subfield, '$.cited_by_count'),'"') AS INT64) AS cited_by_count,
#     TRIM(JSON_EXTRACT(subfield, '$.works_api_url'),'"') AS works_api_url,
#     CAST(TRIM(JSON_EXTRACT(subfield, '$.created_date'),'"') AS DATETIME) AS created_date,
#     COALESCE(
#       CAST(SAFE.PARSE_TIMESTAMP('%FT%H:%M:%E*SZ',
#               TRIM(JSON_EXTRACT(subfield, '$.updated'),'"')) AS DATETIME),
#       CAST(TRIM(JSON_EXTRACT(subfield, '$.updated'),'"') AS DATETIME)
#     ) AS updated,
#     CAST(TRIM(JSON_EXTRACT(subfield, '$.updated_date'),'"') AS DATETIME) AS updated_date,
#   FROM `stone-ground-401723.publicdb_openalex_2024_04.subfields`
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Second level tables

# %% [markdown]
# ### Publishers auxiliary tables

# %% [markdown]
# #### Publishers lineage

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.publishers_lineages;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.publishers_lineages AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(publisher, '$.id'),'"'),'/P')[1] AS INT64) AS publisher_id,
#       JSON_EXTRACT_ARRAY(publisher, '$.lineage') AS lineages,
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.publishers`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(publisher,'$.lineage'))>0
#   )
#   SELECT publisher_id,
#     TRIM(JSON_EXTRACT(lineage, '$.lineage'),'"') AS lineage
#   FROM aux,
#   UNNEST(lineages) lineage
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ####Publishers concepts

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.publishers_concepts;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.publishers_concepts AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(publisher, '$.id'),'"'),'/P')[1] AS INT64) AS publisher_id,
#       JSON_EXTRACT_ARRAY(publisher,'$.x_concepts') AS concepts
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.publishers`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(publisher,'$.x_concepts'))>0
#   )
#   SELECT
#       publisher_id,
#       CAST(TRIM(JSON_EXTRACT(concept, '$.score'),'"') AS FLOAT64) AS score,
#       CAST(SPLIT(TRIM(JSON_EXTRACT(concept, '$.id'),'"'),'/C')[1] AS INT64) AS concept_id,
#   FROM aux,
#   UNNEST(concepts) concept
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ####Publishers counts by year

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.publishers_counts_by_year;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.publishers_counts_by_year AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(publisher, '$.id'),'"'),'/P')[1] AS INT64) AS publisher_id,
#       JSON_EXTRACT_ARRAY(publisher, '$.counts_by_year') AS counts,
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.publishers`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(publisher, '$.counts_by_year'))>0
#   )
#   SELECT
#     publisher_id,
#     CAST(TRIM(JSON_EXTRACT(count, '$.cited_by_count'),'"') AS INT64) AS cited_by_count,
#     CAST(TRIM(JSON_EXTRACT(count, '$.year'),'"') AS INT64) AS year,
#     CAST(TRIM(JSON_EXTRACT(count, '$.works_count'),'"') AS INT64) AS works_coun,
#     CAST(TRIM(JSON_EXTRACT(count, '$.oa_works_count'),'"') AS INT64) AS oa_works_count,
#   FROM aux,
#   UNNEST(counts) count
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ####Publishers roles

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.publishers_roles;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.publishers_roles AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(publisher, '$.id'),'"'),'/P')[1] AS INT64) AS publisher_id,
#       JSON_EXTRACT_ARRAY(publisher, '$.roles') AS roles
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.publishers`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(publisher, '$.roles') )>0
#   )
#   SELECT
#     publisher_id,
#     CAST(TRIM(JSON_EXTRACT(role, '$.works_count'),'"') AS INT64) AS works_count,
#     TRIM(JSON_EXTRACT(role, '$.role'),'"') AS role,
#   FROM aux,
#   UNNEST(roles) role
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Publishers alternate titles

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.publishers_alternate_titles;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.publishers_alternate_titles AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(publisher, '$.id'),'"'),'/P')[1] AS INT64) AS publisher_id,
#       JSON_EXTRACT_ARRAY(publisher, '$.alternate_title') AS alternate_titles
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.publishers`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(publisher, '$.alternate_title'))>0
#   )
#   SELECT publisher_id,
#     TRIM(title,'"') AS alternate_title
#   FROM aux,
#   UNNEST(alternate_titles) title
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ####Publishers country codes

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.publishers_country_codes;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.publishers_country_codes AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(publisher, '$.id'),'"'),'/P')[1] AS INT64) AS publisher_id,
#       JSON_EXTRACT_ARRAY(publisher, '$.country_codes') AS country_codes
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.publishers`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(publisher, '$.country_codes'))>0
#   )
#   SELECT publisher_id,
#     TRIM(country_code,'"') AS country_code
#   FROM aux,
#   UNNEST(country_codes) country_code
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Concepts auxiliary tables

# %% [markdown]
# #### Concepts related concepts

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.concepts_related_concepts;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.concepts_related_concepts AS (
#   WITH aux AS (
#     SELECT  CAST(SPLIT(TRIM(JSON_EXTRACT(concept, '$.id'),'"'),'/C')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(concept, '$.related_concepts') AS related_concepts,
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.concepts`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(concept, '$.related_concepts'))>0
#   )
#   SELECT id AS concept_id,
#     CAST(TRIM(JSON_EXTRACT(related_concept, '$.score'),'"') AS FLOAT64) AS score,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(related_concept, '$.id'),'"'),'/C')[1] AS INT64) AS related_concept_id,
#   FROM aux,
#   UNNEST(related_concepts) related_concept
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Concepts ancestors

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.concepts_ancestors;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.concepts_ancestors AS (
#    WITH aux AS (
#     SELECT  CAST(SPLIT(TRIM(JSON_EXTRACT(concept, '$.id'),'"'),'/C')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(concept, '$.ancestors') AS concepts_ancestors,
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.concepts`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(concept, '$.ancestors'))>0
#   )
#   SELECT id AS concept_id,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(concept_ancestor, '$.id'),'"'),'/C')[1] AS INT64) AS concept_ancestor_id,
#   FROM aux,
#   UNNEST(concepts_ancestors) concept_ancestor
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Concepts counts by year

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.concepts_counts_by_year;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.concepts_counts_by_year AS (
#   WITH aux AS (
#     SELECT  CAST(SPLIT(TRIM(JSON_EXTRACT(concept, '$.id'),'"'),'/C')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(concept,'$.counts_by_year') AS counts_by_year
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.concepts`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(concept,'$.counts_by_year'))>0
#   )
#   SELECT id AS concept_id,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.cited_by_count'),'"') AS INT64) AS cited_by_count,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.year'),'"') AS INT64) AS year,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.works_count'),'"') AS INT64) AS works_count,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.oa_works_count'),'"') AS INT64) AS oa_works_count,
#   FROM aux,
#   UNNEST (counts_by_year) counts
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Authors auxiliary tables

# %% [markdown]
# #### Authors ids

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.authors_ids;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.authors_ids AS (
#   SELECT
#     CAST(TRIM(JSON_EXTRACT(author,'$.ids.mag'),'"') AS INT64) AS mag,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(author,'$.ids.openalex'),'"'),'/A')[1] AS INT64) AS openalex,
#     TRIM(JSON_EXTRACT(author,'$.ids.orcid'),'"') AS orcid,
#     TRIM(JSON_EXTRACT(author,'$.ids.scopus'),'"') AS scopus,
#     TRIM(JSON_EXTRACT(author,'$.ids.twitter'),'"') AS twitter,
#     TRIM(JSON_EXTRACT(author,'$.ids.wikipedia'),'"') AS wikipedia,
#   FROM `stone-ground-401723.publicdb_openalex_2024_04.authors`
#   WHERE JSON_EXTRACT(author,'$.ids') IS NOT NULL
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Authors concepts

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.authors_concepts;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.authors_concepts AS (
#   WITH aux AS (
#     SELECT  CAST(SPLIT(TRIM(JSON_EXTRACT(author, '$.id'),'"'),'/A')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(author,'$.x_concepts') AS concepts
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.authors`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(author,'$.x_concepts'))>0
#   )
#   SELECT id AS author_id,
#     JSON_EXTRACT(concept_info, '$.score') AS score,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(concept_info, '$.id'),'"'),'/C')[1] AS INT64) AS concept_id,
#   FROM aux,
#   UNNEST (concepts) concept_info
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Authors display name alternatives

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.authors_display_name_alternatives;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.authors_display_name_alternatives AS (
#   WITH aux AS (
#     SELECT  CAST(SPLIT(TRIM(JSON_EXTRACT(author, '$.id'),'"'),'/A')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(author,'$.display_name_alternatives') AS display_name_alternatives
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.authors`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(author,'$.display_name_alternatives')) >0
#   )
#   SELECT id AS author_id,
#     TRIM(name,'"') AS display_name_alternative,
#   FROM aux,
#   UNNEST (display_name_alternatives) name
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Authors counts by year

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.authors_counts_by_year;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.authors_counts_by_year AS (
#   WITH aux AS (
#     SELECT  CAST(SPLIT(TRIM(JSON_EXTRACT(author, '$.id'),'"'),'/A')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(author,'$.counts_by_year') AS counts_by_year
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.authors`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(author,'$.counts_by_year')) > 0
#   )
#   SELECT id AS author_id,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.cited_by_count'),'"') AS INT64) AS cited_by_count,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.year'),'"') AS INT64) AS year,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.works_count'),'"') AS INT64) AS works_count,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.oa_works_count'),'"') AS INT64) AS oa_works_count,
#   FROM aux,
#   UNNEST (counts_by_year) counts
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Funders auxiliary tables

# %% [markdown]
# #### Funders concepts

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.funders_concepts;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.funders_concepts AS (
#    WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(funder,'$.id'),'"'),'/F')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(funder,'$.x_concepts') AS concepts ,
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.funders`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(funder,'$.x_concepts'))>0
#   )
#   SELECT id AS funder_id,
#     CAST(TRIM(JSON_EXTRACT(concept,'$.score'),'"') AS FLOAT64) AS score,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(concept,'$.id'),'"'),'/C')[1] AS INT64) AS concept_id,
#   FROM aux,
#   UNNEST(concepts) concept
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Funders counts by year

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.funders_counts_by_year;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.funders_counts_by_year AS (
#   WITH aux AS (
#     SELECT  CAST(SPLIT(TRIM(JSON_EXTRACT(funder,'$.id'),'"'),'/F')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(funder,'$.counts_by_year') AS counts_by_year
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.funders`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(funder,'$.counts_by_year'))>0
#   )
#   SELECT id AS funder_id,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.cited_by_count'),'"') AS INT64) AS cited_by_count,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.year'),'"') AS INT64) AS year,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.works_count'),'"') AS INT64) AS works_count,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.oa_works_count'),'"') AS INT64) AS oa_works_count,
#   FROM aux,
#   UNNEST (counts_by_year) counts
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Funders roles

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.funders_roles;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.funders_roles AS (
#   WITH aux AS (
#     SELECT  CAST(SPLIT(TRIM(JSON_EXTRACT(funder,'$.id'),'"'),'/F')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(funder,'$.roles') AS roles
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.funders`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(funder,'$.roles'))>0
#   )
#   SELECT id AS funder_id,
#     CAST(TRIM(JSON_EXTRACT(role,'$.roles'),'"') AS INT64) AS role,
#     TRIM(JSON_EXTRACT(role,'$.id'),'"') AS related_role_id,
#     CAST(TRIM(JSON_EXTRACT(role,'$.works_count'),'"') AS INT64) AS works_count,
#
#   FROM aux,
#   UNNEST (roles) role
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Funders alternative titles

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.funders_alternate_titles;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.funders_alternate_titles AS (
#   WITH aux AS (
#     SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(funder,'$.id'),'"'),'/F')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(funder,'$.alternate_titles') AS alternate_titles
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.funders`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(funder,'$.alternate_titles'))>0
#   )
#   SELECT
#      id AS funder_id,
#      TRIM(name,'"') AS alternate_title
#   FROM aux,
#   UNNEST (alternate_titles) name
#
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Institutions auxiliary tables

# %% [markdown]
# #### Institutions counts by year

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.institutions_counts_by_year;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.institutions_counts_by_year AS (
#   WITH aux AS (
#     SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(institution, '$.id'),'"'),'/I')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(institution,'$.counts_by_year') AS counts_by_year
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.institutions`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(institution,'$.counts_by_year'))>0
#   )
#   SELECT id AS institution_id,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.cited_by_count'),'"') AS INT64) AS cited_by_count,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.year'),'"') AS INT64) AS year,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.works_count'),'"') AS INT64) AS works_count,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.oa_works_count'),'"') AS INT64) AS oa_works_count,
#   FROM aux,
#   UNNEST (counts_by_year) counts
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Institutions concepts

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.institutions_concepts;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.institutions_concepts AS (
#    WITH aux AS (
#     SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(institution, '$.id'),'"'),'/I')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(institution,'$.x_concepts') AS concepts ,
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.institutions`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(institution,'$.x_concepts'))>0
#   )
#   SELECT id AS institution_id,
#     CAST(TRIM(JSON_EXTRACT(concept,'$.score'),'"') AS FLOAT64) AS score,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(concept,'$.id'),'"'),'/C')[1] AS INT64) AS concept_id,
#   FROM aux,
#   UNNEST(concepts) concept
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Institutions display name alternatives

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.institutions_display_name_alternatives;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.institutions_display_name_alternatives AS (
#   WITH aux AS (
#     SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(institution, '$.id'),'"'),'/I')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(institution,'$.display_name_alternatives') AS display_name_alternatives
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.institutions`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(institution,'$.display_name_alternatives')) >0
#   )
#   SELECT
#      id AS institution_id,
#      TRIM(name,'"') AS display_name_alternatives
#   FROM aux,
#   UNNEST (display_name_alternatives) name
#
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Institutions acronyms

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.institutions_display_name_acronyms;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.institutions_display_name_acronyms AS (
#   WITH aux AS (
#     SELECT  CAST(SPLIT(TRIM(JSON_EXTRACT(institution, '$.id'),'"'),'/I')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(institution,'$.display_name_acronyms') AS display_name_acronyms
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.institutions`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(institution,'$.display_name_acronyms')) >0
#   )
#   SELECT
#      id AS institution_id,
#      TRIM(name,'"') AS display_name_acronyms
#   FROM aux,
#   UNNEST (display_name_acronyms) name
#
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Sources auxiliary tables

# %% [markdown]
# #### Sources host organization lineage

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.sources_host_organization_lineage;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.sources_host_organization_lineage AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(source, '$.id'),'"'),'/S')[1] AS INT64) AS source_id,
#       JSON_EXTRACT_ARRAY(source, '$.host_organization_lineage') AS host_organization_lineage
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.sources`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(source, '$.host_organization_lineage'))>0
#   )
#   SELECT source_id,
#     TRIM(hol,'"') AS host_organization_lineage
#   FROM aux,
#   UNNEST(host_organization_lineage) hol
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Source host organization lineage names

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.sources_host_organization_lineage_names;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.sources_host_organization_lineage_names AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(source, '$.id'),'"'),'/S')[1] AS INT64) AS source_id,
#       JSON_EXTRACT_ARRAY(source, '$.host_organization_lineage_names') AS host_organization_lineage_names
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.sources`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(source, '$.host_organization_lineage_names'))>0
#   )
#   SELECT source_id,
#     TRIM(hol,'"') AS host_organization_lineage_names
#   FROM aux,
#   UNNEST(host_organization_lineage_names) hol
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Source publisher lineage names

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.sources_publisher_lineage_names;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.sources_publisher_lineage_names AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(source, '$.id'),'"'),'/S')[1] AS INT64) AS source_id,
#       JSON_EXTRACT_ARRAY(source, '$.publisher_lineage_names') AS publisher_lineage_names
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.sources`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(source, '$.publisher_lineage_names'))>0
#   )
#   SELECT source_id,
#     TRIM(pl,'"') AS publisher_lineage_names
#   FROM aux,
#   UNNEST(publisher_lineage_names) pl
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Source publisher lineage

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.sources_publisher_lineage;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.sources_publisher_lineage AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(source, '$.id'),'"'),'/S')[1] AS INT64) AS source_id,
#       JSON_EXTRACT_ARRAY(source, '$.publisher_lineage') AS publisher_lineage
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.sources`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(source, '$.publisher_lineage'))>0
#   )
#   SELECT source_id,
#     TRIM(pl,'"') AS publisher_lineage
#   FROM aux,
#   UNNEST(publisher_lineage) pl
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Source host institution lineage

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.sources_host_institution_lineage;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.sources_host_institution_lineage AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(source, '$.id'),'"'),'/S')[1] AS INT64) AS source_id,
#       JSON_EXTRACT_ARRAY(source, '$.host_institution_lineage') AS host_institution_lineage
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.sources`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(source, '$.host_institution_lineage'))>0
#   )
#   SELECT source_id,
#     TRIM(pl,'"') AS host_institution_lineage
#   FROM aux,
#   UNNEST(host_institution_lineage) pl
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Source host institution lineage

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.sources_host_institution_lineage_names;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.sources_host_institution_lineage_names AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(source, '$.id'),'"'),'/S')[1] AS INT64) AS source_id,
#       JSON_EXTRACT_ARRAY(source, '$.host_institution_lineage_names') AS host_institution_lineage_names
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.sources`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(source, '$.host_institution_lineage_names'))>0
#   )
#   SELECT source_id,
#     TRIM(pl,'"') AS host_institution_lineage_names
#   FROM aux,
#   UNNEST(host_institution_lineage_names) pl
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Sources counts by year

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.sources_counts_by_year;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.sources_counts_by_year AS (
#   WITH aux AS (
#     SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(source, '$.id'),'"'),'/S')[1] AS INT64) AS source_id,
#       JSON_EXTRACT_ARRAY(source,'$.counts_by_year') AS counts_by_year
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.sources`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(source,'$.counts_by_year'))>0
#   )
#   SELECT id AS source_id,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.cited_by_count'),'"') AS INT64) AS works_count,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.cited_by_count'),'"') AS INT64) AS oa_works_count,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.cited_by_count'),'"') AS INT64) AS cited_by_count,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.year'),'"') AS INT64) AS year,
#   FROM aux,
#   UNNEST (counts_by_year) counts
# )
# Out:
# Executing query with job ID: b9ab5a0a-97b3-4bd0-8df1-c345949bb535
# Query executing: 1.03s
# ERROR:
#  400 Query error: Unrecognized name: id at [9:10]
#
# Location: US
# Job ID: b9ab5a0a-97b3-4bd0-8df1-c345949bb535

# %% [markdown]
# #### Sources societies

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.sources_societies;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.sources_societies AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(source, '$.id'),'"'),'/S')[1] AS INT64) AS source_id,
#       JSON_EXTRACT_ARRAY(source, '$.societies') AS societies
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.sources`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(source, '$.societies'))>0
#   )
#   SELECT source_id,
#     TRIM(JSON_EXTRACT(soc, '$.organization'),'"') AS organization,
#     TRIM(JSON_EXTRACT(soc, '$.url'),'"') AS url
#   FROM aux,
#   UNNEST(societies) soc
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Sources concepts

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.sources_concepts;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.sources_concepts AS (
#
#     WITH aux AS (
#       SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(source, '$.id'),'"'),'/S')[1] AS INT64) AS source_id,
#         JSON_EXTRACT_ARRAY(source,'$.x_concepts') AS concepts
#           FROM `stone-ground-401723.publicdb_openalex_2024_04.sources`
#       WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(source,'$.x_concepts'))>0
#     )
#     SELECT source_id AS source_id,
#       CAST(SPLIT(TRIM(JSON_EXTRACT(concept,'$.id'),'"'),'/C')[1] AS INT64) AS concept_id,
#       CAST(TRIM(JSON_EXTRACT(concept,'$.score'),'"') AS FLOAT64) AS score,
#     FROM aux,
#     UNNEST (concepts) concept
#
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Sources apc prices

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.sources_apc_prices;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.sources_apc_prices AS (
#     WITH aux AS (
#       SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(source, '$.id'),'"'),'/S')[1] AS INT64) AS source_id,
#         JSON_EXTRACT_ARRAY(source,'$.apc_prices') AS apc_prices
#           FROM `stone-ground-401723.publicdb_openalex_2024_04.sources`
#       WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(source,'$.apc_prices'))>0
#     )
#     SELECT source_id AS source_id,
#       TRIM(JSON_EXTRACT(price,'$.currency'),'"') AS currency,
#       TRIM(JSON_EXTRACT(price,'$.price'),'"') AS price,
#     FROM aux,
#     UNNEST (apc_prices) price
#
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Works auxiliary tables

# %% [markdown]
# #### Works apc

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.works_apc;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.works_apc AS (
#   SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(work, '$.id'),'"'),'/W')[1] AS INT64) AS id,
#     CAST(TRIM(JSON_EXTRACT(work,'$.apc_list.value'),'"') AS INT64) AS value,
#     TRIM(JSON_EXTRACT(work,'$.apc_list.currency'),'"') AS currency,
#     TRIM(JSON_EXTRACT(work,'$.apc_list.provenance'),'"') AS provenance,
#     CAST(TRIM(JSON_EXTRACT(work,'$.apc_list.value_usd'),'"') AS INT64) AS value_usd0,
#     CAST(TRIM(JSON_EXTRACT(work,'$.apc_paid.value'),'"') AS INT64) AS paid_value,
#     TRIM(JSON_EXTRACT(work,'$.apc_paid.currency'),'"') AS paid_currency,
#     TRIM(JSON_EXTRACT(work,'$.apc_paid.provenance'),'"') AS paid_provenance,
#     CAST(TRIM(JSON_EXTRACT(work,'$.apc_paid.value_usd'),'"') AS INT64) AS value_usd,
#   FROM `stone-ground-401723.publicdb_openalex_2024_04.works`
#   WHERE (JSON_EXTRACT(work,'$.apc_list') IS NOT NULL) OR
#       (JSON_EXTRACT(work,'$.apc_paid') IS NOT NULL)
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Works ids

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.works_ids;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.works_ids AS (
#   SELECT
#     SUBSTR(TRIM(JSON_EXTRACT(work,'$.ids.doi'),'"'),17) AS doi,
#     CAST(TRIM(JSON_EXTRACT(work,'$.ids.mag'),'"') AS INT64) AS mag,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(work,'$.ids.openalex'),'"'),'/W')[1] AS INT64) AS openalex,
#     TRIM(JSON_EXTRACT(work,'$.ids.pmid'),'"') AS pmid,
#     TRIM(JSON_EXTRACT(work,'$.ids.pmcid'),'"') AS pmcid,
#   FROM `stone-ground-401723.publicdb_openalex_2024_04.works`
#   WHERE JSON_EXTRACT(work,'$.ids') IS NOT NULL
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Works locations

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.works_locations;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.works_locations AS (
#   WITH aux AS (
#     SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(work, '$.id'),'"'),'/W')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(work,'$.locations') AS locations
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.works`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(work,'$.locations'))>0
#   )
#   SELECT id AS work_id,
#     CAST(TRIM(JSON_EXTRACT(location, '$.is_oa'),'"') AS BOOL) AS is_oa,
#     TRIM(JSON_EXTRACT(location, '$.landing_page_url'),'"') AS landing_page_url,
#     TRIM(JSON_EXTRACT(location, '$.pdf_url'),'"') AS pdf_url,
#     TRIM(JSON_EXTRACT(location, '$.license'),'"') AS license,
#     TRIM(JSON_EXTRACT(location, '$.version'),'"') AS version,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(location, '$.source.id'),'"'),'/S')[1] AS INT64) AS source_id
#   FROM aux,
#   UNNEST (locations) location
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Works best open access location

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.works_best_oa_location;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.works_best_oa_location AS (
#     SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(work, '$.id'),'"'),'/W')[1] AS INT64) AS id,
#       CAST(TRIM(JSON_EXTRACT(work,'$.best_oa_location.is_oa'),'"') AS BOOL) AS is_oa,
#       TRIM(JSON_EXTRACT(work,'$.best_oa_location.landing_page_url'),'"') AS landing_page_url,
#       TRIM(JSON_EXTRACT(work,'$.best_oa_location.pdf_url'),'"') AS pdf_url,
#       TRIM(JSON_EXTRACT(work,'$.best_oa_location.license'),'"') AS license,
#       TRIM(JSON_EXTRACT(work,'$.best_oa_location.version'),'"') AS version,
#       CAST(SPLIT(TRIM(JSON_EXTRACT(work,'$.best_oa_location.source.id'),'"'),'/S')[1] AS INT64) AS source_id,
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.works`
#     WHERE JSON_EXTRACT(work,'$.best_oa_location') IS NOT NULL
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Works primary location

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.works_primary_location;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.works_primary_location AS (
#     SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(work, '$.id'),'"'),'/W')[1] AS INT64) AS id,
#       CAST(TRIM(JSON_EXTRACT(work,'$.primary_location.is_oa'),'"') AS BOOL) AS is_oa,
#       TRIM(JSON_EXTRACT(work,'$.primary_location.landing_page_url'),'"') AS landing_page_url,
#       TRIM(JSON_EXTRACT(work,'$.primary_location.pdf_url'),'"') AS pdf_url,
#       TRIM(JSON_EXTRACT(work,'$.primary_location.license'),'"') AS license,
#       TRIM(JSON_EXTRACT(work,'$.primary_location.version'),'"') AS version,
#       CAST(SPLIT(TRIM(JSON_EXTRACT(work,'$.primary_location.source.id'),'"'),'/S')[1] AS INT64) AS source_id,
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.works`
#     WHERE JSON_EXTRACT(work,'$.primary_location') IS NOT NULL
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Works inverted abstracts

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.works_inverted_abstracts;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.works_inverted_abstracts AS (
#   SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(work, '$.id'),'"'),'/W')[1] AS INT64) AS id,
#     JSON_EXTRACT(work,'$.abstract_inverted_index') AS abstract_inverted_index
#   FROM `stone-ground-401723.publicdb_openalex_2024_04.works`
#   WHERE LENGTH(JSON_EXTRACT(work,'$.abstract_inverted_index'))>5
#     AND JSON_EXTRACT(work,'$.abstract_inverted_index') IS NOT NULL
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Works counts by year

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.works_counts_by_year;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.works_counts_by_year AS (
#   WITH aux AS (
#     SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(work, '$.id'),'"'),'/W')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(work,'$.counts_by_year') AS counts_by_year
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.works`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(work,'$.counts_by_year'))>0
#   )
#   SELECT id AS work_id,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.cited_by_count'),'"') AS INT64) AS cited_by_count,
#     CAST(TRIM(JSON_EXTRACT(counts, '$.year'),'"') AS INT64) AS year,
#
#   FROM aux,
#   UNNEST (counts_by_year) counts
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ####Works related

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.works_related_works;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.works_related_works AS (
#   WITH aux AS (
#     SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(work, '$.id'),'"'),'/W')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(work,'$.related_works') AS related_works
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.works`
#     WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(work,'$.related_works'))>0
#   )
#   SELECT
#      id AS work_id,
#      TRIM(name,'"') AS related_work
#   FROM aux,
#   UNNEST (related_works) name
#
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ####Works authorships

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.works_authorships;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.works_authorships AS (
#   WITH aux_aux AS (
#     WITH aux AS (
#       SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(work, '$.id'),'"'),'/W')[1] AS INT64) AS id,
#         JSON_EXTRACT_ARRAY(work,'$.authorships') AS authorships
#           FROM `stone-ground-401723.publicdb_openalex_2024_04.works`
#       WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(work,'$.authorships'))>0
#     )
#     SELECT id AS work_id,
#       author_order+1 AS author_order,
#       CAST(SPLIT(TRIM(JSON_EXTRACT(authorship, '$.author.id'),'"'),'/A')[1] AS INT64) AS author_id,
#       TRIM(JSON_EXTRACT(authorship, '$.raw_affiliation_string'),'"') AS raw_affiliation_string,
#       TRIM(JSON_EXTRACT(authorship, '$.author_position'),'"') AS author_position,
#       JSON_EXTRACT_ARRAY(authorship, '$.institutions') AS institutions
#     FROM aux,
#     UNNEST (authorships) authorship
#     WITH OFFSET AS author_order
#   )
#   SELECT work_id,
#     author_id,
#     raw_affiliation_string,
#     author_position,
#     author_order,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(institution,'$.id'),'"'),'/I')[1] AS INT64) AS institution_id
#   FROM aux_aux,
#   UNNEST(institutions) institution
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Works mesh

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.works_mesh;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.works_mesh AS (
#
#     WITH aux AS (
#       SELECT  CAST(SPLIT(TRIM(JSON_EXTRACT(work, '$.id'),'"'),'/W')[1] AS INT64) AS id,
#         JSON_EXTRACT_ARRAY(work,'$.mesh') AS works_mesh
#           FROM `stone-ground-401723.publicdb_openalex_2024_04.works`
#       WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(work,'$.mesh'))>0
#     )
#     SELECT id AS work_id,
#       CAST(TRIM(JSON_EXTRACT(mesh, '$.is_major_topic'),'"') AS BOOL) AS is_major_topic,
#       TRIM(JSON_EXTRACT(mesh,'$.qualifier_ui'),'"') AS qualifier_ui,
#       TRIM(JSON_EXTRACT(mesh,'$.descriptor_name'),'"') AS descriptor_name,
#       TRIM(JSON_EXTRACT(mesh,'$.descriptor_ui'),'"') AS descriptor_ui,
#       TRIM(JSON_EXTRACT(mesh,'$.qualifier_name'),'"') AS qualifier_name,
#     FROM aux,
#     UNNEST (works_mesh) mesh
# )

# %% [markdown]
# #### Works concepts

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.works_concepts;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.works_concepts AS (
#
#     WITH aux AS (
#       SELECT
#        CAST(SPLIT(TRIM(JSON_EXTRACT(work, '$.id'),'"'),'/W')[1] AS INT64) AS id,
#        JSON_EXTRACT_ARRAY(work,'$.concepts') AS works_concepts
#           FROM `stone-ground-401723.publicdb_openalex_2024_04.works`
#       WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(work,'$.concepts'))>0
#     )
#     SELECT id AS work_id,
#       CAST(SPLIT(TRIM(JSON_EXTRACT(concept,'$.id'),'"'),'/C')[1] AS INT64) AS concept_id,
#       CAST(TRIM(JSON_EXTRACT(concept,'$.score'),'"') AS FLOAT64) AS score,
#     FROM aux,
#     UNNEST (works_concepts) concept
#
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Works topics

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.works_topics;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.works_topics AS (
#
#     WITH aux AS (
#       SELECT
#        CAST(SPLIT(TRIM(JSON_EXTRACT(work, '$.id'),'"'),'/W')[1] AS INT64) AS id,
#        JSON_EXTRACT_ARRAY(work,'$.topics') AS topics
#           FROM `stone-ground-401723.publicdb_openalex_2024_04.works`
#       WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(work,'$.topics'))>0
#     )
#     SELECT id AS work_id,
#       CAST(SPLIT(TRIM(JSON_EXTRACT(topic,'$.id'),'"'),'/T')[1] AS INT64) AS topic_id,
#       CAST(TRIM(JSON_EXTRACT(topic,'$.score'),'"') AS FLOAT64) AS score,
#     FROM aux,
#     UNNEST (topics) topic
#
# )

# %% [markdown]
# #### Works referenced works

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.works_referenced_works;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.works_referenced_works AS (
#
#     WITH aux AS (
#       SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(work, '$.id'),'"'),'/W')[1] AS INT64) AS id,
#         JSON_EXTRACT_ARRAY(work,'$.referenced_works') AS referenced_works
#           FROM `stone-ground-401723.publicdb_openalex_2024_04.works`
#        WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(work,'$.referenced_works'))>0
#     )
#     SELECT id AS work_id,
#       CAST(SPLIT(TRIM(reference,'"'),'/W')[1] AS INT64) AS referenced_work_id,
#     FROM aux,
#     UNNEST (referenced_works) reference
#
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Works grants

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.works_grants;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.works_grants AS (
#
#     WITH aux AS (
#       SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(work, '$.id'),'"'),'/W')[1] AS INT64) AS id,
#         JSON_EXTRACT_ARRAY(work,'$.grants') AS works_grants
#           FROM `stone-ground-401723.publicdb_openalex_2024_04.works`
#       WHERE ARRAY_LENGTH(JSON_EXTRACT_ARRAY(work,'$.grants'))>0
#     )
#     SELECT id AS work_id,
#       CAST(SPLIT(TRIM(JSON_EXTRACT(grant_,'$.funder'),'"'),'/F')[1] AS INT64) AS funder_id,
#       TRIM(JSON_EXTRACT(grant_,'$.award_id'),'"') AS award_id,
#     FROM aux,
#     UNNEST (works_grants) grant_
#
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Works biblio

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.works_biblio;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.works_biblio AS (
#       SELECT CAST(SPLIT(TRIM(JSON_EXTRACT(work, '$.id'),'"'),'/W')[1] AS INT64) AS id,
#         SUBSTR(TRIM(JSON_EXTRACT(work, '$.doi'),'"'),17) AS doi,
#         TRIM(JSON_EXTRACT(work, '$.doi_registration_agency'),'"') AS doi_registration_agency,
#         TRIM(JSON_EXTRACT(work,'$.biblio.volume'),'"') AS volume,
#         TRIM(JSON_EXTRACT(work,'$.biblio.issue'),'"') AS issue,
#         TRIM(JSON_EXTRACT(work,'$.biblio.first_page'),'"') AS first_page,
#         TRIM(JSON_EXTRACT(work,'$.biblio.last_page'),'"') AS last_page
#       FROM `stone-ground-401723.publicdb_openalex_2024_04.works`
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Topics secondary tables

# %% [markdown]
# #### Topics ids

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.topics_ids;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.topics_ids AS (
#   SELECT
#     CAST(SPLIT(TRIM(JSON_EXTRACT(topic, '$.id'),'"'),'/T')[1] AS INT64) AS topic_id,
#     TRIM(JSON_EXTRACT(topic, '$.openalex'),'"') AS openalex,
#     TRIM(JSON_EXTRACT(topic, '$.wikipedia'),'"') AS wikipedia,
#   FROM `stone-ground-401723.publicdb_openalex_2024_04.topics`
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Topics keywords

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.topics_keywords;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.topics_keywords AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(topic, '$.id'),'"'),'/T')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(topic, '$.keywords') AS kwds,
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.topics`
#   )
#   SELECT id AS topic_id,
#     TRIM(kwd,'"') AS keyword
#   FROM aux,
#   UNNEST(kwds) kwd
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Topics siblings

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.topics_siblings;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.topics_siblings AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(topic, '$.id'),'"'),'/T')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(topic, '$.siblings') AS siblings,
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.topics`
#   )
#   SELECT id AS topic_id,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(sibling, '$.id'),'"'),'/T')[1] AS INT64) AS sibling_id,
#   FROM aux,
#   UNNEST(siblings) sibling
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Domains secondary tables

# %% [markdown]
# #### Domains ids

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.domains_ids;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.domains_ids AS (
#   SELECT
#     CAST(SPLIT(TRIM(JSON_EXTRACT(domain, '$.id'),'"'),'domains/')[1] AS INT64) AS domain_id,
#     TRIM(JSON_EXTRACT(domain, '$.wikidata'),'"') AS wikidata,
#     TRIM(JSON_EXTRACT(domain, '$.wikipedia'),'"') AS wikipedia,
#   FROM `stone-ground-401723.publicdb_openalex_2024_04.domains`
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Domains siblings

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.domains_siblings;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.domains_siblings AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(domain, '$.id'),'"'),'domains/')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(domain, '$.siblings') AS siblings,
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.domains`
#   )
#   SELECT id AS domain_id,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(sibling, '$.id'),'"'),'domains/')[1] AS INT64) AS sibling_id,
#   FROM aux,
#   UNNEST(siblings) sibling
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Domains fields

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.domains_fields;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.domains_fields AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(domain, '$.id'),'"'),'domains/')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(domain, '$.fields') AS fields,
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.domains`
#   )
#   SELECT id AS domain_id,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(field, '$.id'),'"'),'fields/')[1] AS INT64) AS field_id,
#   FROM aux,
#   UNNEST(fields) field
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Domains display name alternatives

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.domains_display_name_alternatives;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.domains_display_name_alternatives AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(domain, '$.id'),'"'),'domains/')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(domain, '$.display_name_alternatives') AS display_name_alternatives,
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.domains`
#   )
#   SELECT id AS domain_id,
#     TRIM(display_name_alternative,'"') AS display_name_alternative,
#   FROM aux,
#   UNNEST(display_name_alternatives) display_name_alternative
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Fields secondary tables

# %% [markdown]
# #### Fields ids

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.fields_ids;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.fields_ids AS (
#   SELECT
#     CAST(SPLIT(TRIM(JSON_EXTRACT(field, '$.id'),'"'),'fields/')[1] AS INT64) AS field_id,
#     TRIM(JSON_EXTRACT(field, '$.wikidata'),'"') AS wikidata,
#     TRIM(JSON_EXTRACT(field, '$.wikipedia'),'"') AS wikipedia,
#   FROM `stone-ground-401723.publicdb_openalex_2024_04.fields`
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Fields siblings

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.fields_siblings;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.fields_siblings AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(field, '$.id'),'"'),'fields/')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(field, '$.siblings') AS siblings,
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.fields`
#   )
#   SELECT id AS field_id,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(sibling, '$.id'),'"'),'fields/')[1] AS INT64) AS sibling_id,
#   FROM aux,
#   UNNEST(siblings) sibling
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Fields subfields

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.fields_subfields;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.fields_subfields AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(field, '$.id'),'"'),'fields/')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(field, '$.subfields') AS subfields,
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.fields`
#   )
#   SELECT id AS field_id,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(subfield, '$.id'),'"'),'subfields/')[1] AS INT64) AS subfield_id,
#   FROM aux,
#   UNNEST(subfields) subfield
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Fields display name alternatives

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.fields_display_name_alternatives;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.fields_display_name_alternatives AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(field, '$.id'),'"'),'fields/')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(field, '$.display_name_alternatives') AS display_name_alternatives,
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.fields`
#   )
#   SELECT id AS field_id,
#     TRIM(display_name_alternative,'"') AS display_name_alternative,
#   FROM aux,
#   UNNEST(display_name_alternatives) display_name_alternative
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Subfields secondary tables

# %% [markdown]
# #### Subfields ids

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.subfields_ids;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.subfields_ids AS (
#   SELECT
#     CAST(SPLIT(TRIM(JSON_EXTRACT(subfield, '$.id'),'"'),'fields/')[1] AS INT64) AS subfield_id,
#     TRIM(JSON_EXTRACT(subfield, '$.wikidata'),'"') AS wikidata,
#     TRIM(JSON_EXTRACT(subfield, '$.wikipedia'),'"') AS wikipedia,
#   FROM `stone-ground-401723.publicdb_openalex_2024_04.subfields`
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Subfields siblings

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.subfields_siblings;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.subfields_siblings AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(subfield, '$.id'),'"'),'subfields/')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(subfield, '$.siblings') AS siblings,
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.subfields`
#   )
#   SELECT id AS subfield_id,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(sibling, '$.id'),'"'),'subfields/')[1] AS INT64) AS sibling_id,
#   FROM aux,
#   UNNEST(siblings) sibling
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Subfields topics

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.subfields_topics;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.subfields_topics AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(subfield, '$.id'),'"'),'subfields/')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(subfield, '$.topics') AS topics,
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.subfields`
#   )
#   SELECT id AS subfield_id,
#     CAST(SPLIT(TRIM(JSON_EXTRACT(topic, '$.id'),'"'),'/T')[1] AS INT64) AS topic_id,
#   FROM aux,
#   UNNEST(topics) topic
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Subfields display name alternatives

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP TABLE IF EXISTS stone-ground-401723.publicdb_openalex_2024_04_rm.subfields_display_name_alternatives;
# CREATE TABLE stone-ground-401723.publicdb_openalex_2024_04_rm.subfields_display_name_alternatives AS (
#   WITH aux AS (
#     SELECT
#       CAST(SPLIT(TRIM(JSON_EXTRACT(subfield, '$.id'),'"'),'fields/')[1] AS INT64) AS id,
#       JSON_EXTRACT_ARRAY(subfield, '$.display_name_alternatives') AS display_name_alternatives,
#     FROM `stone-ground-401723.publicdb_openalex_2024_04.subfields`
#   )
#   SELECT id AS subfield_id,
#     TRIM(display_name_alternative,'"') AS display_name_alternative,
#   FROM aux,
#   UNNEST(display_name_alternatives) display_name_alternative
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Abstracts from inverted abstracts

# %% [markdown]
# A Javascript UDF is created to build the abstracts from the inverted index. It is created on a different dataset.

# %%
# %%bigquery --project=stone-ground-401723
#
# DROP FUNCTION IF EXISTS stone-ground-401723.projectdb_cwts_summer_school_2023.read_join_json;
# CREATE FUNCTION stone-ground-401723.projectdb_cwts_summer_school_2023.read_join_json(d STRING)
# RETURNS STRING
# LANGUAGE js
# AS r"""
#   try {
#     obj = JSON.parse(d);
#     var arr = [];
#     Object.keys(obj.InvertedIndex).forEach(k => obj.InvertedIndex[k].forEach(a => arr[a] = k));
#     text = arr.join(' ');
#   } catch {
#     text = ''
#   }
#
#   return text;
# """;
#
# DROP TABLE IF EXISTS stone-ground-401723.projectdb_cwts_summer_school_2023.works_abstracts;
# CREATE TABLE stone-ground-401723.projectdb_cwts_summer_school_2023.works_abstracts AS (
#   SELECT id,
#     stone-ground-401723.projectdb_cwts_summer_school_2023.read_join_json(abstract_inverted_index) AS abstract
#   FROM `stone-ground-401723.publicdb_openalex_2024_04_rm.works_inverted_abstracts`
#   WHERE abstract_inverted_index IS NOT NULL
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []
